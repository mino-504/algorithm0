# %% [markdown]
# ## 6.2 실습과제
# ----------

# %% [markdown]
# >#### **1. 문제 정의(MD) (예제 그냥 문제 제목)**
# >카운팅 정렬

# %% [markdown]
# >#### **2. 알고리즘 설명(MD)  (알고리즘 설명)**
# >중복 개수를 세아리고 정렬 후 개수만큼 쓰는 알고리즘이다.

# %% [markdown]
# #### **3. 손으로 푼 예제 (![이름][img]/이미지.jpg])  (책 예제 코드 이해 후 사진)**

# %% [markdown]
# ![KakaoTalk_20240523_143550446_01.jpg](attachment:KakaoTalk_20240523_143550446_01.jpg)

# %% [markdown]
# ![KakaoTalk_20240523_143550446.jpg](attachment:KakaoTalk_20240523_143550446.jpg)

# %% [markdown]
# >#### **4. 코드 개요(입력 변수, 출력, 알고리즘 개요) (MD)**
# >##### (코드 개요 설명 1. 입력 변수 2. 출력 3. 함수설명)
# >1. 입력 변수 : counting_sort
# >2. 출력      &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;: 주어진 리스트를 작은순으로 정렬을 한다
# >3. 함수 설명 : 리스트의 개수를 새아리고 낮은수의 개수를 먼저 다 쓰고 그 다음 수로 넘어간다

# %% [markdown]
# ---------

# %% [markdown]
# #### **5. 코드(PY, C)**

# %%
def counting_sort(A) :
    output = [0] * len(A)
    count = [0] * MAX_VAL

    for i in A :
        count[i] += 1

    for i in range(MAX_VAL) :
        count[i] += count[i-1]

    for i in range(len(A)) :
        output[count[A[i]]-1] = A[i]
        count[A[i]] -= 1

    for i in range(len(A)) :
        A[i] = output[i]

MAX_VAL = 10
data = [ 1, 4, 1, 2, 7, 5, 2 ]
print("Original : ", data)
counting_sort(data)
print("Counting : ", data)
# Out:
# Original :  [1, 4, 1, 2, 7, 5, 2]
# Counting :  [1, 1, 2, 2, 4, 5, 7]

# %% [markdown]
# ------

# %% [markdown]
# #### **6. 테스트 코드(PY, C), 입력을 바꾸어서**

# %%
def counting_sort(A) :
    output = [0] * len(A)
    count = [0] * MAX_VAL

    for i in A :
        count[i] += 1

    for i in range(MAX_VAL) :
        count[i] += count[i-1]

    for i in range(len(A)) :
        output[count[A[i]]-1] = A[i]
        count[A[i]] -= 1

    for i in range(len(A)) :
        A[i] = output[i]

MAX_VAL = 15
data = [ 1, 5, 4, 8, 9, 6, 3, 2, 7, 5, 8, 9, 4, 4, 11, 2 ]
print("Original : ", data)
counting_sort(data)
print("Counting : ", data)
# Out:
# Original :  [1, 5, 4, 8, 9, 6, 3, 2, 7, 5, 8, 9, 4, 4, 11, 2]
# Counting :  [1, 2, 2, 3, 4, 4, 4, 5, 5, 6, 7, 8, 8, 9, 9, 11]

# %% [markdown]
# ---------

# %% [markdown]
# #### **7. 수행 결과(MD, 결과 캡춰하여 이미지로 삽입)**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ----------

# %% [markdown]
# >#### **8. 복잡도 분석(MD)**
# >전체 알고리즘은 O(k+n)의 시간 복잡도를 갖는데, k가 작은 수로 제한된다면 시간 복잡도는 O(n)이 된다.

# %% [markdown]
# #### **9. 조별 협력 내용(상호지도)**
# &emsp; 최민호
